# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec
import pandas as pd
import ast  
import pyarrow.parquet as pq

# %%
steam_games = pd.read_parquet('steam_games.parquet')

# %%
steam_games
# Out:
#                                                   genres  \
# 0          [action, casual, indie, simulation, strategy]
# 1                   [free to play, indie, rpg, strategy]
# 2      [casual, free to play, indie, simulation, sports]
# 3                            [action, adventure, casual]
# 5                        [action, adventure, simulation]
# ...                                                  ...
# 32129                 [action, adventure, casual, indie]
# 32130              [casual, indie, simulation, strategy]
# 32131                          [casual, indie, strategy]
# 32132                        [indie, racing, simulation]
# 32133                                    [casual, indie]
#
#                        app_name                     title release_date  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty   2018-01-04
# 1                     Ironbound                 Ironbound   2018-01-04
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians   2017-07-24
# 3                       弹炸人2222                   弹炸人2222   2017-12-07
# 5         Battle Royale Trainer     Battle Royale Trainer   2018-01-04
# ...                         ...                       ...          ...
# 32129              Kebab it Up!              Kebab it Up!   2018-01-04
# 32130            Colony On Mars            Colony On Mars   2018-01-04
# 32131  LOGistICAL: South Africa  LOGistICAL: South Africa   2018-01-04
# 32132             Russian Roads             Russian Roads   2018-01-04
# 32133       EXIT 2 - Directions       EXIT 2 - Directions   2017-09-02
#
#                                                     tags  \
# 0          [strategy, action, indie, casual, simulation]
# 1      [free to play, strategy, indie, rpg, card game...
# 2      [free to play, simulation, sports, casual, ind...
# 3                            [action, adventure, casual]
# 5      [action, adventure, simulation, fps, shooter, ...
# ...                                                  ...
# 32129        [action, indie, casual, violent, adventure]
# 32130              [strategy, indie, casual, simulation]
# 32131                          [strategy, indie, casual]
# 32132                        [indie, simulation, racing]
# 32133  [indie, casual, puzzle, singleplayer, atmosphe...
#
#                                                    specs  price      id  \
# 0                                        [single-player]   4.99  761140
# 1      [single-player, multi-player, online multi-pla...   0.00  643980
# 2      [single-player, multi-player, online multi-pla...   0.00  670290
# 3                                        [single-player]   0.99  767400
# 5                    [single-player, steam achievements]   3.99  772540
# ...                                                  ...    ...     ...
# 32129   [single-player, steam achievements, steam cloud]   1.99  745400
# 32130                [single-player, steam achievements]   1.99  773640
# 32131  [single-player, steam achievements, steam clou...   4.99  733530
# 32132  [single-player, steam achievements, steam trad...   1.99  610660
# 32133   [single-player, steam achievements, steam cloud]   4.99  658870
#
#                       developer
# 0                     Kotoshiro
# 1              Secret Level SRL
# 2                  Poolians.com
# 3                          彼岸领域
# 5           Trickjump Games Ltd
# ...                         ...
# 32129           Bidoniera Games
# 32130        Nikita "Ghost_RUS"
# 32131                    Sacada
# 32132  Laush Dmitriy Sergeevich
# 32133             xropi,stev3ns
#
# [30083 rows x 9 columns]

# %%
steam_games['genres'] = steam_games.genres.apply(ast.literal_eval)
steam_games['tags'] = steam_games.tags.apply(ast.literal_eval)
steam_games['specs'] = steam_games.specs.apply(ast.literal_eval)

# %%
steam_games['keys_vec'] = steam_games.apply(lambda row: list(set(row['tags'] + row['specs'] + row['genres'] )), axis=1)

# %%
steam_games[['title','keys_vec']]
# Out:
#                           title  \
# 0           Lost Summoner Kitty
# 1                     Ironbound
# 2       Real Pool 3D - Poolians
# 3                       弹炸人2222
# 5         Battle Royale Trainer
# ...                         ...
# 32129              Kebab it Up!
# 32130            Colony On Mars
# 32131  LOGistICAL: South Africa
# 32132             Russian Roads
# 32133       EXIT 2 - Directions
#
#                                                 keys_vec
# 0      [single-player, casual, simulation, action, in...
# 1      [replay value, 2d, fantasy, card game, multi-p...
# 2      [in-app purchases, multiplayer, single-player,...
# 3             [action, single-player, adventure, casual]
# 5      [single-player, adventure, simulation, shooter...
# ...                                                  ...
# 32129  [single-player, adventure, casual, steam cloud...
# 32130  [single-player, casual, simulation, indie, ste...
# 32131  [single-player, steam leaderboards, casual, st...
# 32132  [steam trading cards, single-player, racing, s...
# 32133  [single-player, puzzle, casual, atmospheric, s...
#
# [30083 rows x 2 columns]

# %%
steam_games.drop(columns=['tags','specs','genres','app_name','release_date','price','id','developer'], inplace=True)

# %%
steam_games
# Out:
#                           title  \
# 0           Lost Summoner Kitty
# 1                     Ironbound
# 2       Real Pool 3D - Poolians
# 3                       弹炸人2222
# 5         Battle Royale Trainer
# ...                         ...
# 32129              Kebab it Up!
# 32130            Colony On Mars
# 32131  LOGistICAL: South Africa
# 32132             Russian Roads
# 32133       EXIT 2 - Directions
#
#                                                 keys_vec
# 0      [single-player, casual, simulation, action, in...
# 1      [replay value, 2d, fantasy, card game, multi-p...
# 2      [in-app purchases, multiplayer, single-player,...
# 3             [action, single-player, adventure, casual]
# 5      [single-player, adventure, simulation, shooter...
# ...                                                  ...
# 32129  [single-player, adventure, casual, steam cloud...
# 32130  [single-player, casual, simulation, indie, ste...
# 32131  [single-player, steam leaderboards, casual, st...
# 32132  [steam trading cards, single-player, racing, s...
# 32133  [single-player, puzzle, casual, atmospheric, s...
#
# [30083 rows x 2 columns]

# %%
df = steam_games.loc[:, ('title', 'keys_vec')]

model = Word2Vec(df['keys_vec'], vector_size=400, window=10, min_count=1, workers=5)  

def get_vector_for_list(word_list):
    vectors = [model.wv[word] for word in word_list if word in model.wv]
    return sum(vectors) / len(vectors) if vectors else None


df['vector'] = df['keys_vec'].apply(get_vector_for_list)

df = df.dropna(subset=['vector'])
df.reset_index(drop=True, inplace=True)

cosine_similarities = cosine_similarity(list(df['vector']), list(df['vector']))

def get_top_n_recommendations(game_title, n=5):
    game_index = df.query('title==@game_title').index[0]
    
    sim_scores = list(enumerate(cosine_similarities[game_index]))
    
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    top_n_indices = [i for i, _ in sim_scores[1:n+1]]

    recommended_games = df['title'].iloc[top_n_indices].tolist()

    return recommended_games

# %%
get_top_n_recommendations('Final DOOM')
# Out:
# ['DOOM II',
#  'Quake IV',
#  'Return to Castle Wolfenstein',
#  'Ultimate Doom',
#  'Master Levels for Doom II']
